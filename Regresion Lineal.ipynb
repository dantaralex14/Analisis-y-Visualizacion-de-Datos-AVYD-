# %% [markdown]
# ### Clase del 22 de abril de 2024

# %% [markdown]
# #### **Machine Learning**
# <p>  ML  significa "Machine Learning" en inglés, y se refiere a una rama de la inteligencia artificial que se enfoca en el desarrollo de algoritmos y técnicas que permiten a los ordenadores aprender a través de la experiencia y los datos, en lugar de ser programados explícitamente para realizar una tarea.
#
# En otras palabras, el aprendizaje automático se basa en la idea de que las máquinas pueden mejorar su rendimiento en una tarea a medida que reciben más datos y retroalimentación, y utilizan esta información para ajustar sus modelos y algoritmos.
#
# El aprendizaje automático se aplica en una amplia variedad de campos, incluyendo el reconocimiento de imágenes y voz, el procesamiento del lenguaje natural, la detección de fraudes y anomalías, la predicción de riesgos financieros y la optimización de procesos empresariales.</p>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### **Tipos de Apredizaje Automático**
# <p>El aprendizaje automático se puede dividir en dos categorías principales: aprendizaje supervisado y aprendizaje no supervisado.
#
# El <strong>aprendizaje supervisado</strong> es aquel en el que se proporciona al algoritmo de aprendizaje un conjunto de datos etiquetados, es decir, datos que ya tienen una clasificación o etiqueta asignada. El objetivo del algoritmo es aprender a clasificar nuevos datos o predecir valores de salida basados en los datos de entrada. Por ejemplo, un algoritmo de aprendizaje supervisado puede ser entrenado para clasificar correos electrónicos como spam o no spam, o para predecir el precio de una casa en función de sus características.
#
# Por otro lado, el <strong>aprendizaje no supervisado</strong> es aquel en el que no se proporcionan etiquetas para los datos. El objetivo del algoritmo es descubrir patrones y estructuras en los datos sin ninguna guía específica. Por ejemplo, un algoritmo de aprendizaje no supervisado puede ser utilizado para agrupar clientes de una tienda en diferentes categorías basadas en su comportamiento de compra, o para encontrar patrones en grandes conjuntos de datos sin etiquetas.
#
# Podemos afirmar que, mientras que el aprendizaje supervisado se  <em>enfoca en aprender a predecir valores de salida a partir de datos etiquetados </em>, el  <em>aprendizaje no supervisado se enfoca en descubrir patrones y estructuras en los datos </em> sin ninguna guía específica.</p>

# %% [markdown]
# ##### **Tipos de Algoritmos ML**
# Existen varios tipos de algoritmos en el aprendizaje automático (ML), cada uno de ellos con su propia técnica y propósito específico. Aquí hay algunos ejemplos:
#
# 1. Regresión: se utiliza para predecir valores continuos, como el precio de una casa o el salario de una persona.
#
# 2. Clasificación: se utiliza para predecir valores discretos, como si un correo electrónico es spam o no, o si una imagen contiene un gato o un perro.
#
# 3. Clustering: se utiliza para agrupar datos similares en grupos o clústeres, como clientes con comportamientos de compra similares.
#
# 4. Árboles de decisión: se utilizan para representar decisiones y acciones en un formato similar a un árbol, donde cada nodo representa una decisión y cada rama representa una acción.
#
# 5. Redes neuronales: se utilizan para imitar el funcionamiento del cerebro humano y se utilizan para tareas complejas de clasificación y predicción.
#
# 6. Aprendizaje profundo: una subcategoría de las redes neuronales que utiliza múltiples capas de procesamiento para aprender características complejas de los datos.
#
# 7. Aprendizaje por refuerzo: se utiliza para entrenar modelos que puedan tomar decisiones y acciones óptimas en un entorno específico, basándose en la retroalimentación y recompensas recibidas.
#
# Estos son solo algunos ejemplos de los muchos tipos de algoritmos de ML que existen, y la <strong>elección del algoritmo adecuado dependerá de la tarea específica que se quiera resolver</strong>.

# %% [markdown]
# ![]("LR3.png")

# %% [markdown]
# ##### **Regresión Lineal Simple ó Múltiple**
#
# <p>La regresión lineal es un método estadístico que se utiliza para modelar la relación entre una variable dependiente y una o más variables independientes. En su forma más simple, se trata de una función lineal que se ajusta a un conjunto de datos para predecir valores de la variable dependiente en función de los valores de las variables independientes.
#
# En la regresión lineal, se parte de la hipótesis de que la relación entre la variable dependiente y las variables independientes es lineal, lo que significa que la variable dependiente puede expresarse como una combinación lineal de las variables independientes.
#
# El objetivo de la regresión lineal es encontrar los valores de los parámetros de la función lineal que mejor se ajusten a los datos. Esto se logra mediante la minimización de la suma de los errores al cuadrado entre los valores reales de la variable dependiente y los valores predichos por el modelo.
#
# La regresión lineal se utiliza en una amplia variedad de campos, incluyendo la economía, la psicología, la biología, la ingeniería y la ciencia de datos. Es una técnica simple pero poderosa que puede proporcionar información valiosa sobre la relación entre las variables.  </p>

# %% [markdown]
# ![LR5.png](attachment:LR5.png)

# %% [markdown]
# ![LR6.png](attachment:LR6.png)

# %% [markdown]
# ![LR7.png](attachment:LR7.png)

# %% [markdown]
# ![LR8.png](attachment:LR8.png)

# %% [markdown]
# ##### **Regresión Lineal Simple con Python**
# El paquete *statsmodel* ayuda para elaborar la regresión lineal

# %%
# Importamos librerias
import pandas as pd
import numpy as np

# %%
# Leemos dataset csv
data = pd.read_csv("Advertising.csv")

# %%
# Explorar el dataset
data.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
# Importamos statsmodels para obtener la regresión lineal 
import statsmodels.formula.api as smf

# %% [markdown]
# ##### **Relacion de las ventas con la TV** #####

# %%
# Relacionamos la variable independiente TV con la variable dependiente Ventas (Sales)
lm = smf.ols(formula="Sales~TV", data = data).fit()

# %%
lm.params

# Nota el valor de predicción sería Sales = 7.032594 + 0.047537 * TV
# Out:
# Intercept    7.032594
# TV           0.047537
# dtype: float64

# %%
# Determinar el valor del coeficiente de predictibilidad
lm.pvalues
# Out:
# Intercept    1.406300e-35
# TV           1.467390e-42
# dtype: float64

# %%
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Sales   R-squared:                       0.612
# Model:                            OLS   Adj. R-squared:                  0.610
# Method:                 Least Squares   F-statistic:                     312.1
# Date:                Sun, 28 Apr 2024   Prob (F-statistic):           1.47e-42
# Time:                        16:31:11   Log-Likelihood:                -519.05
# No. Observations:                 200   AIC:                             1042.
# Df Residuals:                     198   BIC:                             1049.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      7.0326      0.458     15.360      0.000       6.130       7.935
# TV             0.0475      0.003     17.668      0.000       0.042       0.053
# ==============================================================================
# Omnibus:                        0.531   Durbin-Watson:                   1.935
# Prob(Omnibus):                  0.767   Jarque-Bera (JB):                0.669
# Skew:                          -0.089   Prob(JB):                        0.716
# Kurtosis:                       2.779   Cond. No.                         338.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# Error de predictibilidad
sales_pred = lm.predict(pd.DataFrame(data["TV"]))
sales_pred
# Out:
# 0      17.970775
# 1       9.147974
# 2       7.850224
# 3      14.234395
# 4      15.627218
#          ...
# 195     8.848493
# 196    11.510545
# 197    15.446579
# 198    20.513985
# 199    18.065848
# Length: 200, dtype: float64

# %%
#Graficar la regresión lineal
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
data.plot(kind = "scatter", x = "TV", y="Sales")
plt.plot(pd.DataFrame(data["TV"]), sales_pred, c = "red", linewidth= 3)

# %% [markdown]
# ##### **Actividades**
#
# <p>A partir de aquí crea celdas y agrega tus resultados</p>

# %% [markdown]
# Relacion de venta con las Radios

# %%
# Relacionamos la variable independiente Radio con la variable dependiente Ventas (Sales)
lm = smf.ols(formula="Sales~Radio", data = data).fit()

# %%
lm.params

# Nota el valor de predicción sería Sales lo relacionado con Radio
# Out:
# Intercept    9.311638
# Radio        0.202496
# dtype: float64

# %%
# Determinar el valor del coeficiente de predictibilidad
lm.pvalues
# Out:
# Intercept    3.561071e-39
# Radio        4.354966e-19
# dtype: float64

# %%
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Sales   R-squared:                       0.332
# Model:                            OLS   Adj. R-squared:                  0.329
# Method:                 Least Squares   F-statistic:                     98.42
# Date:                Sun, 28 Apr 2024   Prob (F-statistic):           4.35e-19
# Time:                        16:31:13   Log-Likelihood:                -573.34
# No. Observations:                 200   AIC:                             1151.
# Df Residuals:                     198   BIC:                             1157.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      9.3116      0.563     16.542      0.000       8.202      10.422
# Radio          0.2025      0.020      9.921      0.000       0.162       0.243
# ==============================================================================
# Omnibus:                       19.358   Durbin-Watson:                   1.946
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               21.910
# Skew:                          -0.764   Prob(JB):                     1.75e-05
# Kurtosis:                       3.544   Cond. No.                         51.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# Error de predictibilidad
sales_pred = lm.predict(pd.DataFrame(data["Radio"]))
sales_pred
# Out:
# 0      16.965979
# 1      17.269722
# 2      18.606195
# 3      17.674714
# 4      11.498593
#          ...
# 195    10.060872
# 196    10.303867
# 197    11.194849
# 198    17.816461
# 199    11.053102
# Length: 200, dtype: float64

# %%
# %matplotlib inline
data.plot(kind = "scatter", x = "Radio", y="Sales")
plt.plot(pd.DataFrame(data["Radio"]), sales_pred, c = "red", linewidth= 3)

# %% [markdown]
# Relacion de venta con el peridico

# %%
# Relacionamos la variable independiente Periodico con la variable dependiente Ventas (Sales)
lm = smf.ols(formula="Sales~Newspaper", data = data).fit()

# %%
lm.params

# Nota el valor de predicción sería Sales lo relacionado con Radio
# Out:
# Intercept    12.351407
# Newspaper     0.054693
# dtype: float64

# %%
# Determinar el valor del coeficiente de predictibilidad
lm.pvalues
# Out:
# Intercept    4.713507e-49
# Newspaper    1.148196e-03
# dtype: float64

# %%
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Sales   R-squared:                       0.052
# Model:                            OLS   Adj. R-squared:                  0.047
# Method:                 Least Squares   F-statistic:                     10.89
# Date:                Sun, 28 Apr 2024   Prob (F-statistic):            0.00115
# Time:                        16:31:13   Log-Likelihood:                -608.34
# No. Observations:                 200   AIC:                             1221.
# Df Residuals:                     198   BIC:                             1227.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     12.3514      0.621     19.876      0.000      11.126      13.577
# Newspaper      0.0547      0.017      3.300      0.001       0.022       0.087
# ==============================================================================
# Omnibus:                        6.231   Durbin-Watson:                   1.983
# Prob(Omnibus):                  0.044   Jarque-Bera (JB):                5.483
# Skew:                           0.330   Prob(JB):                       0.0645
# Kurtosis:                       2.527   Cond. No.                         64.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# Error de predictibilidad
sales_pred = lm.predict(pd.DataFrame(data["Newspaper"]))
sales_pred
# Out:
# 0      16.136169
# 1      14.818066
# 2      16.141639
# 3      15.550953
# 4      15.545484
#          ...
# 195    13.106172
# 196    12.794421
# 197    12.701443
# 198    15.972090
# 199    12.827237
# Length: 200, dtype: float64

# %%
# %matplotlib inline
data.plot(kind = "scatter", x = "Newspaper", y="Sales")
plt.plot(pd.DataFrame(data["Newspaper"]), sales_pred, c = "red", linewidth= 3)

# %%
data['Sales_pred'] = 7.032594 + 0.047537 * data['TV']
data['RSE'] = (data['Sales']) - data['Sales_pred']**2

SSD = sum(data['RSE'])
SSD
# Out:
# -39836.568647049666

# %%
# Error residual
# El error estandar residual
RSE = np.sqrt(SSD/(len(data)-2))
RSE
# Esta es la desviación estandar de los residuos
# Out:
# C:\Users\Colibecas\AppData\Local\Temp\ipykernel_1484\3713904938.py:3: RuntimeWarning: invalid value encountered in sqrt
#   RSE = np.sqrt(SSD/(len(data)-2))
# nan

# %%
error = RSE/sales_pred
error
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#        ..
# 195   NaN
# 196   NaN
# 197   NaN
# 198   NaN
# 199   NaN
# Length: 200, dtype: float64

# %%
sales_m = np.mean(data['Sales'])
sales_m
# Out:
# 14.0225

# %%
plt.hist(data['Sales'] - data['Sales_pred'])
# Out:
# (array([ 4., 10., 13., 17., 40., 42., 33., 16., 17.,  8.]),
#  array([-8.3860819 , -6.82624404, -5.26640618, -3.70656832, -2.14673046,
#         -0.5868926 ,  0.97294526,  2.53278312,  4.09262098,  5.65245884,
#          7.2122967 ]),
#  <BarContainer object of 10 artists>)

# %%
# Añadir el Newspaper al modelo existente
lm2 = smf.ols(formula="Sales~TV+Newspaper", data=data).fit()
# Revisemos los parámetros
lm2.params
# Out:
# Intercept    5.774948
# TV           0.046901
# Newspaper    0.044219
# dtype: float64

# %%
# La ecuación del modelo
#Sales = 5.774948 + 0.046901TV+ 0.044219Newspaper
lm2.rsquared
# Out:
# 0.6458354938293271

# %%
data.head()
# Out:
#       TV  Radio  Newspaper  Sales  Sales_pred         RSE
# 0  230.1   37.8       69.2   22.1   17.970858 -300.851726
# 1   44.5   39.3       45.1   10.4    9.147990  -73.285730
# 2   17.2   45.9       69.3    9.3    7.850230  -52.326117
# 3  151.5   41.3       58.5   18.5   14.234450 -184.119553
# 4  180.8   10.8       58.4   12.9   15.627284 -231.311993

# %%
# Hacemos algunas predicciones
sales_pred = lm2.predict(data[['TV', 'Newspaper']])

# %%
SSD = sum((data['Sales']-sales_pred)**2)
SSD
# Out:
# 1918.5618118968275

# %%
RSE = np.sqrt(SSD/(len(data)-3))
RSE
# Out:
# 3.1207198602528856

# %%
lm3 = smf.ols(formula="Sales~TV+Radio",data=data).fit()

lm3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Sales   R-squared:                       0.897
# Model:                            OLS   Adj. R-squared:                  0.896
# Method:                 Least Squares   F-statistic:                     859.6
# Date:                Sun, 28 Apr 2024   Prob (F-statistic):           4.83e-98
# Time:                        16:31:14   Log-Likelihood:                -386.20
# No. Observations:                 200   AIC:                             778.4
# Df Residuals:                     197   BIC:                             788.3
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      2.9211      0.294      9.919      0.000       2.340       3.502
# TV             0.0458      0.001     32.909      0.000       0.043       0.048
# Radio          0.1880      0.008     23.382      0.000       0.172       0.204
# ==============================================================================
# Omnibus:                       60.022   Durbin-Watson:                   2.081
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              148.679
# Skew:                          -1.323   Prob(JB):                     5.19e-33
# Kurtosis:                       6.292   Cond. No.                         425.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
sales_pred = lm3.predict(data[['TV','Radio']])
sales_pred
# Out:
# 0      20.555465
# 1      12.345362
# 2      12.337018
# 3      17.617116
# 4      13.223908
#          ...
# 195     5.364512
# 196     8.152375
# 197    12.768048
# 198    23.792923
# 199    15.157543
# Length: 200, dtype: float64

# %%
data.head()
# Out:
#       TV  Radio  Newspaper  Sales  Sales_pred         RSE
# 0  230.1   37.8       69.2   22.1   17.970858 -300.851726
# 1   44.5   39.3       45.1   10.4    9.147990  -73.285730
# 2   17.2   45.9       69.3    9.3    7.850230  -52.326117
# 3  151.5   41.3       58.5   18.5   14.234450 -184.119553
# 4  180.8   10.8       58.4   12.9   15.627284 -231.311993

# %%
RSE = np.sqrt(SSD/(len(data)-3))
RSE
# Out:
# 3.1207198602528856

# %%
SSD = sum((data['Sales']-sales_pred)**2)
SSD
# Out:
# 556.9139800676181

# %%
RSE/sales_m
# Out:
# 0.22255089037282122

# %%
lm4 = smf.ols(formula="Sales~TV+Radio+Newspaper", data=data).fit()

# %%
lm4.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Sales   R-squared:                       0.897
# Model:                            OLS   Adj. R-squared:                  0.896
# Method:                 Least Squares   F-statistic:                     570.3
# Date:                Sun, 28 Apr 2024   Prob (F-statistic):           1.58e-96
# Time:                        16:31:14   Log-Likelihood:                -386.18
# No. Observations:                 200   AIC:                             780.4
# Df Residuals:                     196   BIC:                             793.6
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      2.9389      0.312      9.422      0.000       2.324       3.554
# TV             0.0458      0.001     32.809      0.000       0.043       0.049
# Radio          0.1885      0.009     21.893      0.000       0.172       0.206
# Newspaper     -0.0010      0.006     -0.177      0.860      -0.013       0.011
# ==============================================================================
# Omnibus:                       60.414   Durbin-Watson:                   2.084
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              151.241
# Skew:                          -1.327   Prob(JB):                     1.44e-33
# Kurtosis:                       6.332   Cond. No.                         454.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
sales_pred = lm3.predict(data[['TV','Radio','Newspaper']])
SSD = sum((data['Sales']-sales_pred)**2)
RSE = np.sqrt(SSD/(len(data)-3-1))

# %%
RSE
# Out:
# 1.6856446415208182

# %%
RSE / sales_m
# Out:
# 0.12020999404676898

# %% [markdown]
# #### Reto
# - Agregar una columna con las predicciones al dataset por cada modelo de regesion lineal
# - Seleccionar y generar un tipo de gráfica que ilustre de manera clara las diferencias entre las ventas y los modelos predictivos
# generados

# %%
lm_tv = smf.ols(formula="Sales ~ TV", data=data).fit()
data['Sales_pred_TV'] = lm_tv.predict(data[['TV']])

# %%
lm_radio = smf.ols(formula="Sales ~ Radio", data=data).fit()
data['Sales_pred_Radio'] = lm_radio.predict(data[['Radio']])

# %%
lm_newspaper = smf.ols(formula="Sales ~ Newspaper", data=data).fit()
data['Sales_pred_Newspaper'] = lm_newspaper.predict(data[['Newspaper']])

# %%
plt.scatter(data['Sales'], data['Sales_pred_TV'], label='TV', color='blue')

# %%
plt.scatter(data['Sales'], data['Sales_pred_Radio'], label='Radio', color='green')

# %%
plt.scatter(data['Sales'], data['Sales_pred_Newspaper'], label='Newspaper', color='red')

# %%
plt.plot(data['Sales'], data['Sales'], color='black', linestyle='--')

# %%
plt.xlabel('Ventas reales')
plt.ylabel('Predicciones')
plt.title('Diferencias entre ventas reales y predicciones de cada modelo')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ¿Cómo me ha ayudado el desarrollo de esta actividad a mejorar mis habilidades en el dominio de los algoritmos de aprendizaje automático?
#
# With respect to the question posed by the professor, regarding the activity done in class which was also assigned as homework, in my personal experience, I can say that I quite enjoyed this activity because I revisited a topic from last semester, which was simple and multiple linear regression. I had previous experience with this type of programming algorithms since the 4th semester with Automata and Formal Languages, then in the 5th semester with Machine Learning, and currently in the 6th semester with Data Mining and Data Analysis and Visualization. So, I already had experience; however, I have learned more about this branch related to AI, which is, in my opinion, quite fascinating, and I liked this. So, that's all from my side.
#
# Exploring the realms of Artificial Intelligence and data analysis has been a fascinating journey for me. It's intriguing to witness how mathematical concepts like linear regression, which I initially encountered in earlier semesters, can be applied and further expanded upon in the context of AI and data mining. Each semester has built upon the foundation laid in the previous ones, allowing me to delve deeper into the complexities of these fields.
#
# What particularly captivates me about AI and data analysis is their potential to unravel insights hidden within vast datasets, guiding decision-making processes and driving innovation across various industries. The interplay between theory and practical application in these subjects has not only enriched my understanding but also sparked a profound curiosity to explore further.
#
# As I continue to delve into the intricacies of AI and data analysis, I eagerly anticipate uncovering new methodologies, algorithms, and techniques that can enhance my problem-solving skills and contribute to meaningful advancements in the field. The dynamic nature of this domain ensures that there's always something new to learn and discover, keeping me engaged and motivated to push the boundaries of my knowledge.
#
# In conclusion, while my journey through AI and data analysis has been challenging at times, it has also been immensely rewarding. I look forward to embracing future opportunities to deepen my expertise and make impactful contributions to this ever-evolving field.

# %% [markdown]
# Dantar Alejandro Ortiz Vega 6-D
#
# Ingenieria en Computacion Inteligente
#
# Facultad de Ingenieria Mecanica y Electrica
#
# 24 de abril del 2024
#
# Regresion Lineal
#
# ![image.png](attachment:image.png)
